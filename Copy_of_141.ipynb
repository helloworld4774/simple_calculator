# %% [markdown]
# <a href="https://colab.research.google.com/github/helloworld4774/simple_calculator/blob/main/Copy_of_141.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 1: Data Wrangling with Python

# %% [markdown]
# ## Sprint 4: Capstone Project

# %% [markdown]
# ## About this Sprint
#
# It is time for your first Capstone Project.
# You will work on this project for the whole Sprint.
#
# We are glad you have successfully reached the final Sprint of this Module.
# You will put everything you have learned in this Module to work.
# The outcome of this Module should potentially serve as your portfolio item.
#
# Unlike with previous projects, this time, you are free to choose a dataset to explore from three suggested ones.
# As you will have to solve a provided problem, there will not be a list of predefined questions you have to answer - be creative and explore any data dimensions you deem worth analyzing.
#
# Although this might seem scary, this is how data science looks like in the industry.
# Often, it's your responsibility to not only give answers using the data but to raise questions first.
# The more creatively you look at this project, the better.
# Good luck!
#
# ## Objectives for this Part
#
# - Practice identifying opportunities for data analysis.
# - Practice performing EDA.
# - Practice working with data from Kaggle.
# - Practice visualizing data with Matplotlib & Seaborn.
# - Practice reading data, performing queries, and filtering data using Pandas.
#
# ## Problems
#
# Choose one of the three provided problems.
# The outcomes are usually better if the problem that you are working on is interesting for you.
# This way you will come up with more ideas, what can be explored and analysed.
#
# ### COVID-19 crisis
#
# <div><img width="400px" height="auto" src="https://images.unsplash.com/photo-1574515944794-d6dedc7150de?ixlib=rb-1.2.1&ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&auto=format&fit=crop&w=1532&q=80" /></div>
#
# The world is still struggling with one of the most rapidly spreading pandemics.
# There are a lot of people who say that data is the best weapon we can use in this "Corona Fight."
#
# Imagine that you are one of the best data scientists in your country.
# The president of your country asked you to analyze the COVID-19 patient-level data of South Korea and prepare your homeland for the next wave of the pandemic.
# You, as the lead data scientist of your country **have to create and prove a plan of fighting the pandemics in your country** by analyzing the provided data.
# You must get the most critical insights using learned data science techniques and present them to the lead of your country.
#
# The link to the [Kaggle dataset is here](https://www.kaggle.com/kimjihoo/coronavirusdataset/).
#
# ### 2016 US presidential elections
#
# <div><img width="400px" height="auto" src="https://images.unsplash.com/photo-1583340806569-6da3d5ea9911?ixlib=rb-1.2.1&ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&auto=format&fit=crop&w=1315&q=80" /></div>
#
# In 2016, Donald Trump lost the popular vote, yet he won the electoral vote, securing four years in the Oval Office.
# This has been a shock to Democratic supporters all around the world.
#
# Imagine you travel back in time to 2016.
# As soon as you step out of your time capsule, the Democratic Party hires you.
# They want you, the best data scientist across time and space, **to explain what happened and what should have been done differently**.
# They want you to **prepare them for the 2020 presidential elections**.
#
# The Party has some tips for you - inspect the voters.
# What are Trump supporters?
# What do they feature?
# What are our supporters?
# Where should focus next?
# Any pro-Trump states?
# Cities?
#
# The Democrats were kind enough to share [a Kaggle dataset](https://www.kaggle.com/benhamner/2016-us-election) with you on the 2016 U.S. elections.
# Use the data to help the Democrats.
#
# ### Fatal Police Shooting in the United States
#
# <div><img width="400px" height="auto" src="https://images.unsplash.com/photo-1606352466047-7cef02b312bb?ixlib=rb-1.2.1&ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&auto=format&fit=crop&w=1662&q=80" /></div>
#
# [Police brutality in the United States](https://en.wikipedia.org/wiki/Police_brutality_in_the_United_States) has been a national issue since the 20th century.
# The public safety of U.S. citizens is a typical argument to justify the controversially high number of fatal shootings.
#
# You are a contractor to the United States Department of Justice.
# **You have been given a case to investigate fatal police shootings throughout the United States of America, provide a list of issues, and propose a plan on how to tackle these issues**.
#
# The department offered some tips - the public opinion indicates that there's something systematically fishy about the police actions against civilians.
# We also know that some states differ from the others, some cities are different from others, race equality is still an unanswered question.
# There's also some talk about huge spendings on police, rumors about mental issues of those getting shot.
# Government is all about prioritizing - use the data to list issues with the police activity and propose a plan which issues to tackle first and how.
#
# You are given one dataset to start with.
# Try to search for more datasets to enrich your data analysis.
#
# Here's the dataset: [Fatal Police Shootings in the U.S. '15 - '17](https://www.kaggle.com/washingtonpost/police-shootings).
#
# ## Requirements
#
# - Perform data cleaning and feature engineering. Work with features - handle missing data if needed, use Pandas date APIs, create other additional features.
# - Perform exploratory data analysis. Describe the data with basic statistical parameters - mean, median, quantiles, etc. Use parameters that give you the most important statistical insights of the data. Grouping the data and analyzing the groups - using Pandas aggregate methods. Visualize the data - you can use line, scatter, histogram plots, density plots, regplots, etc.
# - Provide clear explanations in your notebook. Your explanations should inform the reader what you are trying to achieve, what results did you get, and what these results mean.
# - Present the project - the data, methods, and results.
# - Provide suggestions about how your analysis can be improved.
#
# ## Bonus Challenges
#
# As a data scientists you will spend significant amount of your time learning new things.
# Sometimes you will do that for fun, but most of the time you will have an urgent problem and you will need to quickly learn some new skill to be able to solve it.
# It is very important to gradually build this skill - it is extremely valuable for all data scientists.
# The bonus challenges are designed to simulate these types of situations.
# These challenges require you to do something that we haven't covered in the course yet.
# Instead of trying to do all of the bonus challenges, concentrate on just one or two and do them well.
# All of the bonus challenges are optional - no points will be deducted if you skip them.
#
# - Try dimensionality reduction algorithm (e.g. PCA, t-SNE, Autoencoder).
# - Try clustering your data.
# - Try a machine learning model to explain relationships between features and predict new values.
# - Try to use a statistical significance test.
#
# ## Evaluation Criteria
#
# - Adherence to the requirements. How well did you meet the requirements?
# - Visualization quality. Did you use charts effectively to visualize patterns in the data? Are your visualizations properly labeled? Did you use colors effectively? Did you adhere to the principle of proportional ink?
# - Code quality. Was your code well-structure? Did you use the appropriate levels of abstraction? Did you remove commented out and unused code? Did you adhere to the PEP8?
# - Code performance. Did you use the suitable algorithms and data structures to solve the problems?
# - Delivery of the presentation. How clear are your reasoning and explanations?
# - Bonus challenges. Have you put extra effort to do one or more of the bonus challenges (no points will be deducted if you skip them)?
#
# ## Correction
#
# During your project correction, you should present your project as if talking to a product manager and senior data analyst working in your team.
# You will have to find the right balance between explaining the business side and the technical aspects of your work.
# You can assume that both of your colleagues have a strong understanding of and are very interested in the business aspect of your project, so be sure to clearly explain what new insights you've found while analyzing the dataset and which directions look the most promising for further research.
# However, you should also spend time explaining the technical aspects of your work, especially the more complex or unconventional choices.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import json
import pycountry
import plotly.express as px
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint

# %% [markdown]
# Installing packages

# %%
# !pip3 install pycountry
# !pip3 install  --upgrade matplotlib

# %% [markdown]
# ## Introduction
#
# The Washington Post is compiling a database of every fatal shooting in the United States by a police officer in the line of duty since January 1, 2015.
# The Post is documenting only those shootings in which a police officer, in the line of duty, shot and killed a civilian. We have the following features -
#
# 1. id : a unique identifier for each victim
# 2. name: the name of the victim
# 3. date: the date of the fatal shooting in YYYY-MM-DD format
# 4. manner_of_death:
#  * shot
#  * shot and Tasered
# 5. armed: indicates that the victim was armed with some sort of implement that a police officer believed could inflict harm
#
#   * undetermined: it is not known whether or not the victim had a weapon
#   * unknown: the victim was armed, but it is not known what the object was
#   * unarmed: the victim was not armed
# 6. age: age of the victim
# 7. gender: gender of the victim
# 8. race: race of the victim
#   * W: White, non-Hispanic
#   * B: Black, non-Hispanic
#   * A: Asian
#   * N: Native American
#   * H: Hispanic
#   * O: Other
#   * None: unknown
# 9. city: the municipality where the fatal shooting took place
# 10. state: two-letter postal code abbreviation
# 11. signs of mental illness:  (True/False)
# 12. threat_level :
#     * attack : general criteria for the attack label was that there was the most direct and immediate threat to life. That would include incidents where officers or others were shot at, threatened with a gun, attacked with other weapons or physical force, etc. The attack category is meant to flag the highest level of threat.
#
#     * other, undetermined : The other and undetermined categories represent all remaining cases. Other includes many incidents where officers or others faced significant threats.
#
# 13. flee: News reports have indicated the victim was moving away from officers
#
#   * Foot
#   * Car
#   * Not fleeing
#
# 14. body_camera: News reports have indicated an officer was wearing a body camera and it may have recorded some portion of the incident.(True/False)

# %% [markdown]
# We will answer the following questions:-
#
# Q.1 What does the age distribution look like?
#
# Q.2 How many more males to females are there?
#
# Q.3 Are some days more likely to see more killings?
#
# Q.4 Which race has had the most people killed?
#
# Q.5 How does the shootings look like across the map of the USA?
#
# Q.6 Which does the choice of weapon distribution look like?
#
# Additional:
# Clustering Data using DBSSCAN

# %% [markdown]
# Importing data of fatal school shootings in the US.

# %%
df = pd.read_csv("database1.csv", index_col='id')
df
# Out:
#                     name        date   manner_of_death       armed   age  \
# id
# 3             Tim Elliot  2015-01-02              shot         gun  53.0
# 4       Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 5     John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 8        Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 9      Michael Rodriguez  2015-01-04              shot    nail gun  39.0
# ...                  ...         ...               ...         ...   ...
# 8053      Arthur C. Page  2022-05-21              shot     unarmed   NaN
# 8054  Billy Joe Reynolds  2022-05-21              shot         gun  43.0
# 8057                 NaN  2022-05-21              shot       knife  51.0
# 8061      Charles Gamboa  2022-05-21              shot         gun  56.0
# 8060                 NaN  2022-05-22              shot         gun   NaN
#
#      gender race             city state  signs_of_mental_illness threat_level  \
# id
# ...

# %% [markdown]
# Replacing Abbreviations

# %%
race = {'A': "Asian", 'B':"Black",'W': "White", 'H': "Hispanic", 'O': "Others", 
        "N" : "Native American"}
df['race'].replace(race,inplace=True)
gender = { 'M' : "Male", 'F' : "Female"}
df['gender'].replace(gender,inplace=True)
state_name = []
for state in df['state']:
  state_name.append(pycountry.subdivisions.get(code="US-"+ state).name)
df['state'] = state_name
df.head()
# Out:
#                   name        date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot  2015-01-02              shot         gun  53.0   Male
# 4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0   Male
# 5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0   Male
# 8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0   Male
# 9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0   Male
#
#         race           city       state  signs_of_mental_illness threat_level  \
# id
# 3      Asian        Shelton  Washington                     True       attack
# 4      White          Aloha      Oregon                    False       attack
# 5   Hispanic        Wichita      Kansas                    False        other
# 8      White  San Francisco  California                     True       attack
# 9   Hispanic          Evans    Colorado                    False       attack
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7395 entries, 3 to 8060
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     7022 non-null   object
#  1   date                     7395 non-null   object
#  2   manner_of_death          7395 non-null   object
#  3   armed                    7186 non-null   object
#  4   age                      6960 non-null   float64
#  5   gender                   7380 non-null   object
#  6   race                     6003 non-null   object
#  7   city                     7395 non-null   object
#  8   state                    7395 non-null   object
#  9   signs_of_mental_illness  7395 non-null   bool
#  10  threat_level             7395 non-null   object
#  11  flee                     6688 non-null   object
#  12  body_camera              7395 non-null   bool
#  13  longitude                6683 non-null   float64
# ...

# %% [markdown]
# ### Q.1 What does the distribution of age look like?

# %%
plt.figure(figsize=(15, 10))
xtik = np.arange(0, df.age.max(), 5).tolist()
xtik.insert(0, 0)
xlabel = ["{}-{}".format(i, i+4) for i in range(0, 90, 5)]
xlabel.append('90+')
plot = sns.histplot(data=df, x='age', bins=np.arange(0, df.age.max()+5, 5))
plot.bar_label(plot.containers[0]);
plot.set_xticks(np.arange(0, df.age.max(), 5));
plot.set_xticklabels(xlabel, rotation=(-45), fontsize=10, va='top', ha='left')
df.age.describe()
# Out:
# count    6960.000000
# mean       37.141523
# std        12.944272
# min         2.000000
# 25%        27.000000
# 50%        35.000000
# 75%        45.000000
# max        92.000000
# Name: age, dtype: float64

# %% [markdown]
# Here we can see around 50% of the victims were between 27 and 45 years old.

# %% [markdown]
# ### Q.2 How many more males to females are there?

# %%
plt.figure(figsize=(8, 6))
ax1 = sns.countplot(data=df, y=df.gender);
ax1.set(title="Number of fatal shootings by gender 2015-2022", xlabel='Count',
        ylabel="Gender");
ax1.bar_label(ax1.containers[0]);

# %% [markdown]
# We see roughly 20 times more men as many women.

# %% [markdown]
# ### Q.3 Are we more likely to see killings on some days over others?

# %%
df['weekday'] = pd.to_datetime(df.date).dt.day_name()
plt.figure(figsize=(10, 4))
ax = sns.countplot(data=df, x='weekday');
ax.set(title='Fatal police shootings by day 2015-2022 ',
       xlabel='Day of the week')
ax.bar_label(ax.containers[0]);

# %% [markdown]
# We find Tuesday to be the day on which the maximum killings occur 1123 in comparison to the lowest which is on Saturday having 983 killings.

# %% [markdown]
# ### Q.4 Of which races were the most people killed?

# %%
fig, ax = plt.subplots(figsize=(15, 6));
ax = sns.countplot(x=df.race, color='blue',
                   order=df['race'].value_counts().index)
ax.set(title="Count of fatal police shooting victims 2015-2022",
       xlabel="Races", ylabel="Counts");
ax.bar_label(ax.containers[0]);

# %% [markdown]
# While it is true that the White race had the highest victims,it might be helpful to look at this with respect to the races' own population sizes [1]

# %%
dh_race_pop = pd.DataFrame(columns=["White", "Black", "Hispanic", "Asian",
                                    "Native American", "Others"])
dh_race_pop.loc[0] = [235, 42, 39, 20, 6.79, 28]
races_in_millions = dh_race_pop.loc[0]
df_races = df.race.value_counts()/races_in_millions

# %% [markdown]
# Plotting the bar

# %%
fig, ax = plt.subplots(figsize=(15, 6));
ax.bar(x=df_races.index, height=df_races, color='maroon');
ax.bar_label(ax.containers[0]);
plt.xlabel("U.S. Population by Race");
plt.title("Count of Fatal police shootings per million 2015 - 2022");
plt.ylabel("Deaths per million");

# %% [markdown]
# So we can see in this plot,black race has the highest killings of 39 per million.

# %% [markdown]
# ### Q.5 How does the shootings look like across the map of the USA?

# %%
dh = df.loc[:, ['latitude', 'longitude', 'race', 'name', 'state']]
dh = dh.dropna()
fig = px.scatter_mapbox(dh, lat="latitude", lon="longitude", color='race',
                        hover_data=["name", "state"],
                        zoom=4, height=500, width=1000,
                        mapbox_style="carto-positron",
                        title="Fatal Police Shootings Map 2015-2022")
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Here we can see most of the killings happen in the east coast perhaps due to more people living on the east coast. Let's try to see this with charts

# %%
df2 = pd.read_csv("fips1.csv", index_col="ID", dtype={"STATEFP":str} )
df2["shoot_per_state"] = dh.groupby("state").race.count().to_list()
df2["shooting_per_state_per_million"] = df2["shoot_per_state"]/df2['population_in_millions']
df2.head(5)
# Out:
#    STATEFP       STATE  population_in_millions  shoot_per_state  \
# ID
# 0       01     Alabama                    5.03              106
# 1       02      Alaska                    0.73               35
# 2       04     Arizona                    7.27              238
# 3       05    Arkansas                    3.01               75
# 4       06  California                   39.23              801
#
#     shooting_per_state_per_million abbrev
# ID
# 0                        21.073559     AK
# 1                        47.945205     AL
# 2                        32.737276     AR
# 3                        24.916944     AZ
# 4                        20.418047     CA

# %%
px.choropleth(df2, locations='abbrev', locationmode="USA-states",
              hover_data=['STATE', 'population_in_millions'],
              color='shooting_per_state_per_million',
              title='Fatal Police shootings choropleth map 2015-2022',
              scope="usa", height=500, width=900)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Although the concentration of police shootings was high in the Eastern States, the above choropleth map shows another picture,small states like Alaska and New Mexico have the highest shootings per million.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(data=df2, x='population_in_millions', y="shoot_per_state").set(
    title="Shootings vs population(millions) per state",
    xlabel="Population(million)", ylabel="Shooting");
print("The pearson correlation is",
      df2['population_in_millions'].corr(df2['shoot_per_state']))
# Out:
# The pearson correlation is 0.9006882222021165

# %% [markdown]
# Certainly there is a pretty strong correlation between population and shootings per million.Also with a slightly higher slope for countries , we ask the question , do smaller (in population) states have higher shootings per million

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(data=df2, x='population_in_millions',
            y="shooting_per_state_per_million").set(
                title="Shootings vs population(millions) per state",
                xlabel="Population(million)", ylabel="Shooting per million");
print("Pearson correlation is", df2['population_in_millions'].corr
      (df2['shooting_per_state_per_million']))
# Out:
# Pearson correlation is -0.2105059714398017

# %% [markdown]
# A small negative correlation does suggest that smaller states might have higher shootings per million

# %% [markdown]
# ### Q.5 What does choice of weapon distribution look like?

# %%
df_armed_count = df.armed.value_counts().iloc[:10]
fig, ax = plt.subplots(figsize=(15, 5))
ax = sns.countplot(x=df.armed, order=df.armed.value_counts().iloc[:10].index,
                   hue=df.signs_of_mental_illness)
ax.bar_label(ax.containers[0]);
ax.bar_label(ax.containers[1]);

# %% [markdown]
# Here we see that a higher percentage of  victims with signs of mental illness were armed with knifes/machetes/swords than guns, perhaps because it is harder to get a gun with mental illnesses?
#
# Let's check if states with stricter gun laws [2] also correlate with higher percentage of armed by guns victims.

# %%
df_gun = pd.read_csv("csvData.csv")
armed_guns = df.loc[df.armed == 'gun'].groupby('state').count().armed
armed_all_weapons = df.groupby('state').count().armed
armed_gun_percent = (armed_guns / armed_all_weapons)

armed_gun_percent = pd.DataFrame(armed_gun_percent.drop(
    labels=['District of Columbia']))
armed_gun_percent = armed_gun_percent.reset_index()
armed_gun_percent = armed_gun_percent.rename(columns={"state": "State",
                                                      "armed":"armed_gun_%"})
armed_gun_percent = armed_gun_percent.merge(df_gun, on='State')
armed_gun_percent.head(5)
# Out:
#         State  armed_gun_%  lawsRank grade2019  gunDeathRate
# 0     Alabama     0.705882        38         F         21.70
# 1      Alaska     0.666667        42         F         20.74
# 2     Arizona     0.578462        45         F         15.29
# 3    Arkansas     0.607843        40         F         18.96
# 4  California     0.442216         1         A          7.45

# %% [markdown]
# Source :

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x=armed_gun_percent.gunDeathRate,
            y=armed_gun_percent['armed_gun_%']).set(
                title='Gun Death Rate vs Armed by gun % per state',
                xlabel='Gun Death Rate ',
                ylabel='Victim armed by guns by %')
print("The pearson corelation is",
      armed_gun_percent.gunDeathRate.corr(armed_gun_percent['armed_gun_%']))
# Out:
# The pearson corelation is 0.6020769295971347

# %% [markdown]
# States with higher gun death rate also have higher number of victims armed by gun percentage

# %% [markdown]
# #### Clustering with DBSCAN

# %%
dk = df.loc[:, ['latitude', 'longitude']]
dk= dk.dropna()
coords = dk.to_numpy()
kms_per_radian = 6371.0088  #Radius of earth
epsilon = 30 / kms_per_radian
db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree',
            metric='haversine').fit(np.radians(coords))
cluster_labels = db.labels_
num_clusters = len(set(cluster_labels))
clusters = pd.Series([coords[cluster_labels == n] for n in range(num_clusters)])
print('Number of clusters: {}'.format(num_clusters))
clusters
# Out:
# Number of clusters: 839
# 0      [[47.247, -123.122], [47.16, -122.485], [47.22...
# 1      [[45.487, -122.892], [45.175, -122.437], [45.5...
# 2      [[37.695, -97.281], [37.673, -97.413], [37.704...
# 3      [[37.763, -122.422], [37.93, -121.299], [38.26...
# 4      [[40.384, -104.692], [39.726, -104.772], [39.7...
#                              ...
# 834                                 [[46.372, -102.319]]
# 835                                  [[45.819, -94.409]]
# 836                                 [[36.863, -101.214]]
# 837                                 [[36.728, -110.255]]
# 838                                  [[26.611, -81.075]]
# Length: 839, dtype: object

# %%
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)
centermost_points = clusters.map(get_centermost_point)
lats, lons = zip(*centermost_points)
rep_points = pd.DataFrame({'lon':lons, 'lat':lats})
rs = rep_points
fig, ax = plt.subplots(figsize=[10, 6])
rs_scatter = ax.scatter(rs['lon'], rs['lat'], c='#12ac59', edgecolor='None', alpha=0.7, s=120)
df_scatter = ax.scatter(df['longitude'], df['latitude'], c='k', alpha=0.9, s=3)
ax.set_title('Full data set vs DBSCAN reduced .set')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.legend([df_scatter, rs_scatter], ['Full set', 'Reduced set'], loc='upper right')
plt.show()

# %% [markdown]
# Here we can see how we have represented the whole dataset of 6683 values by 839 clusters

# %% [markdown]
# ### Conclusions

# %% [markdown]
# (1)Around 50% of the victims were between 27 and 45 years old.
#
# (2)There 20 times more male victims than female victims.
#
# (3) Tuesday on average has seen the highest number of shootings with 1123 the most popular shootings day and Saturday the lowest with 983 victims
#
# (4) Although white race in absolute numbers has the highest victims killed (3053), victims per million is the highest for Blacks with (39)victims per million of their population
#
# (5)
# *   Higher percentage of  victims with signs of mental illness were armed with knifes/machetes/swords than guns
#
# *   A very strong correlation is observed (0.9 between population and shootings per million is observed.
#
# *  A small negative correlation(0.21) between shootings per million and population does suggest that smaller states might have higher shootings per million.
#
#
# * A decent correlation(0.60) between victims armed by (gun to other weapons) suggests that states with higher gun death rate also have higher number of victims armed by gun percentage
#
# (6) We have represented the whole dataset of 6683 values by 839 clusters

# %% [markdown]
# Improvement:-
#
# (1) PCA, Unsupervised clustering can be implemented
#
# (2) Label / One Hot Encoding and K-Prototypes can be used to mix categorical
# and numerical data for further processing

# %% [markdown]
# Sources :-
#
# [1] https://www.census.gov/library/stories/2021/08/improved-race-ethnicity-measures-reveal-united-states-population-much-more-multiracial.html - Census 2021
#
# [2] https://worldpopulationreview.com/state-rankings/strictest-gun-laws-by-state - Gun law strictness by state
